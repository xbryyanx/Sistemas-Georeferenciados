# %% [markdown]
# GEOPANDAS
#
# GeoPandas, como sugiere el nombre, amplia la popular biblioteca de clencia de datos pandas agregando soporte para datos geoespaciales.
# La estructura de datos principal en GeoPandas es geopandas. GeoDataFrame, una subclase de pandas.DataFrame, que puede almacenar columnas de geometría y realizar operaciones espaciales. El geopandas. GeoSeries, una subclase de pandas.Series, que maneja las geometrías. Por lo tanto, GeoDataFrame es una combinación de pandas.Series, con datos tradicionales (numéricos, booleanos, de texto, etc.) y geopandas.GeoSeries, con geometrías (puntos, polígonos, etc.). Puedes tener tantas columnas con geometrías como desees.

# %%
import geopandas 
from geodatasets import get_path

path_to_data = get_path("nybb")
gdf = geopandas.read_file(path_to_data)
gdf
# Out:
#    BoroCode       BoroName     Shape_Leng    Shape_Area  \
# 0         5  Staten Island  330470.010332  1.623820e+09
# 1         4         Queens  896344.047763  3.045213e+09
# 2         3       Brooklyn  741080.523166  1.937479e+09
# 3         1      Manhattan  359299.096471  6.364715e+08
# 4         2          Bronx  464392.991824  1.186925e+09
#
#                                             geometry
# 0  MULTIPOLYGON (((970217.022 145643.332, 970227....
# 1  MULTIPOLYGON (((1029606.077 156073.814, 102957...
# 2  MULTIPOLYGON (((1021176.479 151374.797, 102100...
# 3  MULTIPOLYGON (((981219.056 188655.316, 980940....
# 4  MULTIPOLYGON (((1012821.806 229228.265, 101278...

# %%
path_to_data
# Out:
# '/Users/bryanmontoya/Library/Caches/geodatasets/nybb_16a.zip.unzip/nybb_16a/nybb.shp'

# %%
#determinar el tipo de objeto
type(gdf)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
# familiarizarte con las siguientes lineas de codigo y comenta para que sirven
gdf #imprime geodataframe
gdf.head() #muestra primeros 5 elementos de geodataframe 
gdf.tail() #muestra ultimos 5 elementos de geodataframe
# Out:
#              Shape_Leng    Shape_Area  \
# BoroCode
# 5         330470.010332  1.623820e+09
# 4         896344.047763  3.045213e+09
# 3         741080.523166  1.937479e+09
# 1         359299.096471  6.364715e+08
# 2         464392.991824  1.186925e+09
#
#                                                    geometry
# BoroCode
# 5         MULTIPOLYGON (((970217.022 145643.332, 970227....
# 4         MULTIPOLYGON (((1029606.077 156073.814, 102957...
# 3         MULTIPOLYGON (((1021176.479 151374.797, 102100...
# 1         MULTIPOLYGON (((981219.056 188655.316, 980940....
# 2         MULTIPOLYGON (((1012821.806 229228.265, 101278...

# %% [markdown]
# AREA

# %%
gdf = gdf.set_index("BoroCode")

# %%
gdf
# Out:
#              Shape_Leng    Shape_Area  \
# BoroCode
# 5         330470.010332  1.623820e+09
# 4         896344.047763  3.045213e+09
# 3         741080.523166  1.937479e+09
# 1         359299.096471  6.364715e+08
# 2         464392.991824  1.186925e+09
#
#                                                    geometry
# BoroCode
# 5         MULTIPOLYGON (((970217.022 145643.332, 970227....
# 4         MULTIPOLYGON (((1029606.077 156073.814, 102957...
# 3         MULTIPOLYGON (((1021176.479 151374.797, 102100...
# 1         MULTIPOLYGON (((981219.056 188655.316, 980940....
# 2         MULTIPOLYGON (((1012821.806 229228.265, 101278...

# %%
gdf = gdf.set_index("BoroName")

# %%
gdf
# Out:
#                BoroCode     Shape_Leng    Shape_Area  \
# BoroName
# Staten Island         5  330470.010332  1.623820e+09
# Queens                4  896344.047763  3.045213e+09
# Brooklyn              3  741080.523166  1.937479e+09
# Manhattan             1  359299.096471  6.364715e+08
# Bronx                 2  464392.991824  1.186925e+09
#
#                                                         geometry
# BoroName
# Staten Island  MULTIPOLYGON (((970217.022 145643.332, 970227....
# Queens         MULTIPOLYGON (((1029606.077 156073.814, 102957...
# Brooklyn       MULTIPOLYGON (((1021176.479 151374.797, 102100...
# Manhattan      MULTIPOLYGON (((981219.056 188655.316, 980940....
# Bronx          MULTIPOLYGON (((1012821.806 229228.265, 101278...

# %%
gdf["area"] = gdf.area
gdf["area"]
# Out:
# BoroName
# Staten Island    1.623822e+09
# Queens           3.045214e+09
# Brooklyn         1.937478e+09
# Manhattan        6.364712e+08
# Bronx            1.186926e+09
# Name: area, dtype: float64

# %%
gdf
# Out:
#                BoroCode     Shape_Leng    Shape_Area  \
# BoroName
# Staten Island         5  330470.010332  1.623820e+09
# Queens                4  896344.047763  3.045213e+09
# Brooklyn              3  741080.523166  1.937479e+09
# Manhattan             1  359299.096471  6.364715e+08
# Bronx                 2  464392.991824  1.186925e+09
#
#                                                         geometry          area
# BoroName
# Staten Island  MULTIPOLYGON (((970217.022 145643.332, 970227....  1.623822e+09
# Queens         MULTIPOLYGON (((1029606.077 156073.814, 102957...  3.045214e+09
# Brooklyn       MULTIPOLYGON (((1021176.479 151374.797, 102100...  1.937478e+09
# Manhattan      MULTIPOLYGON (((981219.056 188655.316, 980940....  6.364712e+08
# Bronx          MULTIPOLYGON (((1012821.806 229228.265, 101278...  1.186926e+09

# %%
gdf["boundary"] = gdf.boundary
gdf["boundary"]
gdf
# Out:
#                BoroCode     Shape_Leng    Shape_Area  \
# BoroName
# Staten Island         5  330470.010332  1.623820e+09
# Queens                4  896344.047763  3.045213e+09
# Brooklyn              3  741080.523166  1.937479e+09
# Manhattan             1  359299.096471  6.364715e+08
# Bronx                 2  464392.991824  1.186925e+09
#
#                                                         geometry  \
# BoroName
# Staten Island  MULTIPOLYGON (((970217.022 145643.332, 970227....
# Queens         MULTIPOLYGON (((1029606.077 156073.814, 102957...
# Brooklyn       MULTIPOLYGON (((1021176.479 151374.797, 102100...
# Manhattan      MULTIPOLYGON (((981219.056 188655.316, 980940....
# Bronx          MULTIPOLYGON (((1012821.806 229228.265, 101278...
#
#                        area                                           boundary
# BoroName
# Staten Island  1.623822e+09  MULTILINESTRING ((970217.022 145643.332, 97022...
# ...

# %%
gdf["centroid"] = gdf.centroid
gdf["centroid"]
gdf
# Out:
#                BoroCode     Shape_Leng    Shape_Area  \
# BoroName
# Staten Island         5  330470.010332  1.623820e+09
# Queens                4  896344.047763  3.045213e+09
# Brooklyn              3  741080.523166  1.937479e+09
# Manhattan             1  359299.096471  6.364715e+08
# Bronx                 2  464392.991824  1.186925e+09
#
#                                                         geometry  \
# BoroName
# Staten Island  MULTIPOLYGON (((970217.022 145643.332, 970227....
# Queens         MULTIPOLYGON (((1029606.077 156073.814, 102957...
# Brooklyn       MULTIPOLYGON (((1021176.479 151374.797, 102100...
# Manhattan      MULTIPOLYGON (((981219.056 188655.316, 980940....
# Bronx          MULTIPOLYGON (((1012821.806 229228.265, 101278...
#
#                        area  \
# BoroName
# Staten Island  1.623822e+09
# Queens         3.045214e+09
# Brooklyn       1.937478e+09
# Manhattan      6.364712e+08
# Bronx          1.186926e+09
#
# ...
